# %%
from gevent.pywsgi import WSGIServer
from app import app


http_server = WSGIServer(("127.0.0.1", 8000), app)
http_server.serve_forever()
# Out:
# 127.0.0.1 - - [2023-01-26 16:24:28] "GET / HTTP/1.1" 200 258 0.011183
# 127.0.0.1 - - [2023-01-26 16:24:29] "GET /static/flask_docker.png HTTP/1.1" 200 16028 0.186147
# 127.0.0.1 - - [2023-01-26 16:24:29] "GET /favicon.ico HTTP/1.1" 404 331 0.000837
# 127.0.0.1 - - [2023-01-26 16:25:12] "GET / HTTP/1.1" 200 258 0.000000
# 127.0.0.1 - - [2023-01-26 16:25:12] "GET /static/flask_docker.png HTTP/1.1" 304 192 0.003996
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gevent\_ffi\loop.py", line 270, in python_check_callback
#     def python_check_callback(self, watcher_ptr): # pylint:disable=unused-argument
# KeyboardInterrupt
# 2023-01-26T13:25:26Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       2 from app import app
#       5 http_server = WSGIServer(("127.0.0.1", 8000), app)
# ...

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/",username='root',password='pass' ,authSource="admin")

# %%
[{"id": animal["id"], "name": animal["name"], "type": animal["type"]} for animal in client["animal_db"].animal_tb.find()]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pymongo\pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 [{"id": animal["id"], "name": animal["name"], "type": animal["type"]} for animal in client["animal_db"].animal_tb.find()]
#
# Input In [18], in <listcomp>(.0)
# ----> 1 [{"id": animal["id"], "name": animal["name"], "type": animal["type"]} for animal in client["animal_db"].animal_tb.find()]
#
# ...

# %%
import pymongo
client = pymongo.MongoClient(host='mongodb://localhost',
                             port=27017, 
                             username='root', 
                             password='pass',
                             authSource="admin")
[{"id": animal["id"], "name": animal["name"], "type": animal["type"]} for animal in client["animal_db"].animal_tb.find()]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pymongo\pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Input In [19], in <cell line: 7>()
#       1 import pymongo
#       2 client = pymongo.MongoClient(host='mongodb://localhost',
#       3                              port=27017,
#       4                              username='root',
#       5                              password='pass',
#       6                              authSource="admin")
# ...
